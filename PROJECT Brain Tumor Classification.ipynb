# %% [markdown]
# ### Load Modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Prepare/collect data

# %%
import os

path = os.listdir('C:/Users/HP/Desktop/ML/brain tumor/Training')
classes = {'no_tumor':0, 'pituitary_tumor':1}

# %%
import cv2
X = []
Y = []
for cls in classes:
    pth = os.path.join("C:/Users/HP/Desktop/ML/brain tumor/Training", cls)
    for j in os.listdir(pth):
        img = cv2.imread(pth+'/'+j, 0)
        img = cv2.resize(img, (200,200))
        X.append(img)
        Y.append(classes[cls])

# %%
X = np.array(X)
Y = np.array(Y)

X_updated = X.reshape(len(X), -1)

# %%
np.unique(Y)
# Out:
# array([0, 1])

# %%
pd.Series(Y).value_counts()
# Out:
# 1    827
# 0    395
# Name: count, dtype: int64

# %%
X.shape, X_updated.shape
# Out:
# ((1222, 200, 200), (1222, 40000))

# %% [markdown]
# ### Visualize data

# %%
plt.imshow(X[0], cmap='gray')

# %% [markdown]
# ### Prepare data

# %%
X_updated = X.reshape(len(X), -1)
X_updated.shape
# Out:
# (1222, 40000)

# %% [markdown]
# ### Split Data

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X_updated, Y, random_state=10,
                                               test_size=.20)

# %%
xtrain.shape, xtest.shape
# Out:
# ((977, 40000), (245, 40000))

# %% [markdown]
# ### Feature Scaling

# %%
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
xtrain = xtrain/255
xtest = xtest/255
print(xtrain.max(), xtrain.min())
print(xtest.max(), xtest.min())
# Out:
# 255 0
# 255 0
# 1.0 0.0
# 1.0 0.0

# %% [markdown]
# ### Feature Selection: PCA

# %%
from sklearn.decomposition import PCA

# %%
print(xtrain.shape, xtest.shape)

pca = PCA(.98)
# pca_train = pca.fit_transform(xtrain)
# pca_test = pca.transform(xtest)
pca_train = xtrain
pca_test = xtest
# Out:
# (977, 40000) (245, 40000)

# %%
# print(pca_train.shape, pca_test.shape)
# print(pca.n_components_)
# print(pca.n_features_)

# %% [markdown]
# ### Train Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
import warnings
warnings.filterwarnings('ignore')

lg = LogisticRegression(C=0.1)
lg.fit(xtrain, ytrain)
# Out:
# LogisticRegression(C=0.1)

# %%
sv = SVC()
sv.fit(xtrain, ytrain)
# Out:
# SVC()

# %% [markdown]
# ### Evaluation

# %%
print("Training Score:", lg.score(xtrain, ytrain))
print("Testing Score:", lg.score(xtest, ytest))
# Out:
# Training Score: 1.0
# Testing Score: 0.9591836734693877

# %%
print("Training Score:", sv.score(xtrain, ytrain))
print("Testing Score:", sv.score(xtest, ytest))
# Out:
# Training Score: 0.9938587512794268
# Testing Score: 0.963265306122449

# %% [markdown]
# ### Prediction

# %%
pred = sv.predict(xtest)

# %%
misclassified=np.where(ytest!=pred)
misclassified
# Out:
# (array([ 36,  51,  68, 120, 212, 214, 220, 227, 239], dtype=int64),)

# %%
print("Total Misclassified Samples: ",len(misclassified[0]))
print(pred[36],ytest[36])
# Out:
# Total Misclassified Samples:  9
# 0 1

# %% [markdown]
# ### TEST MODEL

# %%
dec = {0:'No Tumor', 1:'Positive Tumor'}

# %%
plt.figure(figsize=(12,8))
p = os.listdir('C:/Users/HP/Desktop/ML/brain tumor/Testing')
c=1
for i in os.listdir('C:/Users/HP/Desktop/ML/brain tumor/Testing/no_tumor')[:9]:
    plt.subplot(3,3,c)
    
    img = cv2.imread('C:/Users/HP/Desktop/ML/brain tumor/Testing/no_tumor/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = sv.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1

# %%
plt.figure(figsize=(12,8))
p = os.listdir('C:/Users/HP/Desktop/ML/brain tumor/Testing')
c=1
for i in os.listdir('C:/Users/HP/Desktop/ML/brain tumor/Testing/pituitary_tumor')[:9]:
    plt.subplot(3,3,c)
    
    img = cv2.imread('C:/Users/HP/Desktop/ML/brain tumor/Testing/pituitary_tumor/'+i,0)
    img1 = cv2.resize(img, (200,200))
    img1 = img1.reshape(1,-1)/255
    p = sv.predict(img1)
    plt.title(dec[p[0]])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    c+=1
